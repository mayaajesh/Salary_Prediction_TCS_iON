# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('salary_prediction.csv')

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
#Data has 1470 observations and 35 features

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# # Exploratory Data analysis

# %%
#Count plot of Buisiness travel
plt.figure(figsize = (8, 6))
target=sns.countplot(x ='BusinessTravel', data = data)
total = float(len(data))
plt.title('Count plot of Buisiness travel', fontsize=20)
for p in target.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    target.annotate(percentage, (x, y),ha='right')
plt.show()

# %%
#This plot shows that 71% employees travel rarely

# %%
#Count plot of Job Role
plt.figure(figsize = (8, 6))
target=sns.countplot(x ='JobRole', data = data)
total = float(len(data))
plt.title('Count plot of JobRole', fontsize=20)
plt.xticks(rotation=90)
for p in target.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    target.annotate(percentage, (x, y),ha='right')
plt.show()

# %%
#Most of the employees are sales executives. Human resourses constitute only 3.5% in job role

# %%
#Pie chart of Educational field
education = data['EducationField'].value_counts()
plt.figure(figsize = (8, 8))
education.plot(kind = "pie",autopct='%.0f%%')
plt.title('Education Field',fontsize=20)
plt.show()

# %%
#This plot reveals that majority in the dataset are from life science.

# %%
#Pie chart of gender
gender = data['Gender'].value_counts()
plt.figure(figsize = (8, 8))
gender.plot(kind = "pie",autopct='%.0f%%')
plt.title('Gender',fontsize=20)
plt.show()

# %%
#60% of the employees are male and 40% are female

# %%
#Pie chart of MaritalStatus
m_status = data['MaritalStatus'].value_counts()
plt.figure(figsize = (8, 8))
m_status.plot(kind = "pie",autopct='%.0f%%')
plt.title('MaritalStatus',fontsize=20)
plt.show()

# %%
#46% are married 32% are single and 22% are divorced

# %%
plt.figure(figsize=(10,10))
plt.title('Job Role vs Monthly income with Experience as hue',size=15)
plt.xticks(rotation=90)
sns.scatterplot(y ='MonthlyIncome',x= 'JobRole',hue='TotalWorkingYears', data=data)
plt.show()

# %%
#From the plot it is clear that manager and research director are highly paid job roles. Research assistant, laboratory technician and human resource are less paid job roles. 
 #For less paid jobs there is no significant increase in monthly salary even after gaining some experience.

# %%
#Number of companies worked vs job satisfaction
plt.figure(figsize=(10,10))  
plt.title('Number of companies worked vs Job satisfaction level',size=15)
plt.xticks(rotation=90)
sns.lineplot(y ='JobSatisfaction',x='NumCompaniesWorked', data=data)
plt.show()

# %%
#As number of companies worked increases job satisfaction decreases

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Checking for missing values

# %%
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#The data has no missing values

# %%
#Checking unique values and removing columns that are not useful in modelling

# %%
data['EmployeeCount'].nunique()
# Out:
# 1

# %%
data['EmployeeNumber'].nunique()
# Out:
# 1470

# %%
data['Over18'].nunique()
# Out:
# 1

# %%
data['StandardHours'].nunique()
# Out:
# 1

# %%
#Removing employee count,Over18,StandardHours  since these features contains only one value. Dropping EmployeeNumber as all values are unique. 
data.drop(['EmployeeCount','Over18','StandardHours','EmployeeNumber','Attrition','RelationshipSatisfaction',],axis=1,inplace=True)

# %%
data.dtypes
# Out:
# Age                         int64
# BusinessTravel             object
# DailyRate                   int64
# Department                 object
# DistanceFromHome            int64
# Education                   int64
# EducationField             object
# EnvironmentSatisfaction     int64
# Gender                     object
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                    object
# JobSatisfaction             int64
# MaritalStatus              object
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# OverTime                   object
# PercentSalaryHike           int64
# PerformanceRating           int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# WorkLifeBalance             int64
# YearsAtCompany              int64
# YearsInCurrentRole          int64
# ...

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
label_encoded=LabelEncoder()
for i in data.columns:
    if data[i].dtype == object:
        data[i]=label_encoded.fit_transform(data[i])

# %%
data.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EnvironmentSatisfaction  Gender  HourlyRate  ...  \
# 0               1                        2       0          94  ...
# 1               1                        3       1          61  ...
# 2               4                        4       1          92  ...
# 3               1                        4       0          56  ...
# 4               3                        1       1          40  ...
#
#    PercentSalaryHike  PerformanceRating  StockOptionLevel  TotalWorkingYears  \
# ...

# %% [markdown]
# ### Removing biased features
# Obtaining correlation between features

# %%
#splitting dataset into features and target. y is the target 
y = data['MonthlyIncome']
x = data.drop('MonthlyIncome', axis = 1)

# %%
#correlation heatma 
correlate=x.corr()
plt.figure(figsize=(16,16))
ax = sns.heatmap(correlate, annot=True, linewidths=0.1, linecolor='white',cmap="Greens")

# %%
#Removing highly correlated features
#Features with correlation greater than 0.75 and -0.75 are removing
x.drop(['PercentSalaryHike','YearsWithCurrManager','YearsInCurrentRole', 'JobLevel'],axis=1, inplace=True)

# %% [markdown]
# ### Outlier detection

# %%
plt.figure(figsize=(20,7))
x.boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
#The features with outliers are plotted separately

# %%
plt.figure(figsize=(4,6))
plt.subplot(2,1,1)
sns.boxplot(y=x['NumCompaniesWorked'])
plt.title('Number of companies worked')
plt.subplot(2,1,2)
plt.title('TrainingTimesLastYear')
sns.boxplot(y=x['TrainingTimesLastYear'])
plt.tight_layout()
plt.show()
sns.boxplot(y=x['StockOptionLevel'])
plt.title('StockOptionLevel')
plt.tight_layout()
plt.show()
sns.boxplot(y=x['YearsAtCompany'])
sns.boxplot(y=x['YearsAtCompany'])
plt.tight_layout()
plt.show()
sns.boxplot(y=x['YearsSinceLastPromotion'])
sns.boxplot(y=x['YearsSinceLastPromotion'])
plt.tight_layout()
plt.show()

# %%
#Outlier handling
for i in ['NumCompaniesWorked','TrainingTimesLastYear','StockOptionLevel','YearsAtCompany','YearsSinceLastPromotion']:
    q1 = x[i].quantile(0.25) 
    q3 = x[i].quantile(0.75) 
    iqr = q3 - q1 
    upper_limit = q3 + 1.5 * iqr
    lower_limit = q1 - 1.5 * iqr 
#Replacing outliers with upper and lower limit
    x[i][x[i]>upper_limit] = upper_limit
    x[i][x[i]<lower_limit] = lower_limit

# %%
#Plotting after outlier handling
plt.figure(figsize=(4,6))
plt.subplot(2,1,1)
sns.boxplot(y=x['NumCompaniesWorked'])
plt.title('Number of companies worked')
plt.subplot(2,1,2)
plt.title('TrainingTimesLastYear')
sns.boxplot(y=x['TrainingTimesLastYear'])
plt.tight_layout()
plt.show()
sns.boxplot(y=x['StockOptionLevel'])
plt.title('StockOptionLevel')
plt.tight_layout()
plt.show()
sns.boxplot(y=x['YearsAtCompany'])
sns.boxplot(y=x['YearsAtCompany'])
plt.tight_layout()
plt.show()
sns.boxplot(y=x['YearsSinceLastPromotion'])
sns.boxplot(y=x['YearsSinceLastPromotion'])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Modeling

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state =42, test_size = 0.2)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LinearRegression
logistic_model = LinearRegression()
logistic_model.fit(x_train,y_train)
y_predict_logistic = logistic_model.predict(x_test)
print("R squared value of Logistic Regression is : ",r2_score(y_test,y_predict_logistic))
# Out:
# R squared value of Logistic Regression is :  0.5792903400495932

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsRegressor
r_value = []
#creating neighbors as 3 to 15
neighbors = np.arange(3,15)
for k in neighbors:
    # taking instances for KNN into variable name classifier using the method minkowski
    knn_r = KNeighborsRegressor(n_neighbors=k, metric="minkowski")
    knn_r.fit(x_train,y_train)
    y_pred_knn = knn_r.predict(x_test)
    r2 = r2_score(y_test,y_pred_knn)
    r_value.append(r2)

# %%
r_value
# Out:
# [-0.4389480061644673,
#  -0.324652504748552,
#  -0.2880508811648417,
#  -0.25073200272223617,
#  -0.2191670894211375,
#  -0.19095873225452942,
#  -0.1606585335070705,
#  -0.1301008705476685,
#  -0.12911301960001542,
#  -0.12136755201327687,
#  -0.09993592573427246,
#  -0.09548942878730582]

# %%
#since this model gives negative r2 value, not considering this model

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVR
svm_regressor=SVR(kernel='rbf')
svm_regressor.fit(x_train,y_train)
y_pred_svm=svm_regressor.predict(x_test)
print("R squared value of SVM is : ",r2_score(y_test,y_pred_svm))
# Out:
# R squared value of SVM is :  -0.2331001998588309

# %%
#This model also gives negative r2 value, so not considering this model

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest=RandomForestRegressor()
random_forest.fit(x_train,y_train)
y_pred_random_forest=random_forest.predict(x_test)
print("R squared value of Random Forest model is : ",r2_score(y_test,y_pred_random_forest))
# Out:
# R squared value of Random Forest model is :  0.8600520656270865

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
decision_tree=DecisionTreeRegressor()
decision_tree.fit(x_train,y_train)
y_pred_decision_tree=decision_tree.predict(x_test)
print("R squared value of Decision Tree is : ",r2_score(y_test,y_pred_decision_tree))
# Out:
# R squared value of Decision Tree is :  0.7548724897831016

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
grad_boost=GradientBoostingRegressor()
grad_boost.fit(x_train, y_train)
y_pred_grad_boost=grad_boost.predict(x_test)
print("R squared value of gradient boosting is : ",r2_score(y_test,y_pred_grad_boost))
# Out:
# R squared value of gradient boosting is :  0.8751178271340139

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBRegressor
xg_boost=XGBRegressor()
xg_boost.fit(x_train,y_train)
y_pred_xg_boost=xg_boost.predict(x_test)
print("R squared value  of XG Boost is : ",r2_score(y_test,y_pred_xg_boost))
# Out:
# R squared value  of XG Boost is :  0.8434550312744873

# %%
#Gradient Boost gives good r2 score. Therefore it can be used for modelling
